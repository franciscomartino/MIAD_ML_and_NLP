# %% [markdown]
# ![image info](https://raw.githubusercontent.com/albahnsen/MIAD_ML_and_NLP/main/images/banner_1.png)

# %% [markdown]
# # Taller: Redes Neuronales
#
# En este taller podrán poner en práctica sus conocimientos sobre la construcción e implementación de redes neuronales de una capa y multicapa. El taller está constituido por 4 puntos, en los cuales deberan seguir las intrucciones de cada numeral para su desarrollo.

# %% [markdown]
# ## Datos predicción probabilidad de admisión a la universidad
#
# En este taller se usará el conjunto de datos de admisiones a una universidad proveniente de la base de datos de Kaggle. Cada observación contiene la probabilidad de que un estudiante sea admitido por la universidad, dadas distintas variables predictoras como el puntaje del examén TOEFL y GRE, el promedio (GPA), entre otras. El objetivo es predecir la probabilidad de admissión de cada estudiante. Para más detalles pueden visitar el siguiente enlace: [datos](https://www.kaggle.com/mohansacharya/graduate-admissions).

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Importación librerías
import numpy as np
import keras 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from keras import initializers
from keras import optimizers
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import Dropout

from livelossplot import PlotLossesKeras
from keras import backend as K
import keras.optimizers as opts

# %%
# Carga de datos de archivo .csv
data = pd.read_csv('https://raw.githubusercontent.com/albahnsen/MIAD_ML_and_NLP/main/datasets/universityGraduateAdmissions.csv', index_col=0)
data.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# 2                  1              0.76
# 3                  1              0.72
# 4                  1              0.80
# 5                  0              0.65

# %%
# Hitogramas de las varaibles del dataset
data.hist(bins=25, figsize=(15,15))
plt.show()

# %%
# Definición de variables predictoras (X)
X = data.drop(data.columns[-1], axis=1)
# Definición de variable de interés (y)
Y = data[data.columns[-1]]

# %%
# Separación de variables predictoras (X) y variable de interés (y) en set de entrenamiento y test usandola función train_test_split
xTrain, xTest, yTrain, yTest = train_test_split(X,Y,test_size=0.3, random_state=22)

# %% [markdown]
# ## Punto 1 - Red Neuronal de una capa
#
# En la celda 1 creen una **red neuronal de una capa** con la librería Keras, que prediga la probabilidad de admisión de los estudiantes, usando los sets de entrenamiento y test definidos anteriormente. Pueden usar la función de perdida, el optimizador y el número de épocas que consideren pertinentes para el modelo, justificando su selección. Finalmente, grafiquen la pérdida del modelo vs el número de épocas en el set de entrenamiento y validación, y presenten el desempeño del modelo con las métricas error absoluto medio (MAE) y error cuadrático medio (MSE).

# %%
# Celda 1

yTrain =  pd.DataFrame(yTrain)

# Normalización de variables predictoras (X) con la función StandardScaler
from sklearn.preprocessing import StandardScaler

# Definición de la función StandardScaler
scaler = StandardScaler()
scaler.fit(X)

# Transformación de los set de entrenamiento y test
xTrain = pd.DataFrame(data=scaler.transform(xTrain), columns=xTrain.columns, index=xTrain.index)
xTest = pd.DataFrame(data=scaler.transform(xTest), columns=xTest.columns, index=xTest.index)

xTrain = np.array(xTrain)
yTrain = np.array(yTrain)

xTest = np.array(xTest)
yTest = np.array(yTest)

# %%
# Definición de dimensiones de salida, varaibles de interés
output_var = yTrain.shape[1]
print(output_var, ' output variables')

# Definición de dimensiones de entrada, varaibles predictoras
dims = xTrain.shape[1]
print(dims, 'input variables')
# Out:
# 1  output variables
# 7 input variables

# %%
K.clear_session()

# Definición red neuronal con la función Sequential()
model = Sequential()
# Definición de la capa densa con un tamaño de salida igual a output_var y un input_shape de dims
model.add(Dense(output_var, input_shape=(dims,)))

# Impresión de la arquitectura de la red neuronal
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 8
#
# =================================================================
# Total params: 8
# Trainable params: 8
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Definición de función de perdida. Se usa mean_squared_error dado que es un ejercicio de regresión
model.compile(optimizer='sgd', loss='mean_squared_error',  metrics=['mean_squared_error', 'mean_absolute_error'])

# %%
# Entrenamiento de la red neuronal con 50 épocas
model.fit(xTrain, yTrain, 
          verbose=1, 
          epochs=50, 
          validation_data=(xTest, yTest),
          callbacks=[PlotLossesKeras()])
# Out:
# Loss
# 	training         	 (min:    0.004, max:    0.962, cur:    0.004)
# 	validation       	 (min:    0.004, max:    0.831, cur:    0.004)
# mean_absolute_error
# 	training         	 (min:    0.049, max:    0.817, cur:    0.049)
# 	validation       	 (min:    0.045, max:    0.741, cur:    0.045)
# mean_squared_error
# 	training         	 (min:    0.004, max:    0.962, cur:    0.004)
# 	validation       	 (min:    0.004, max:    0.831, cur:    0.004)
# 11/11 [==============================] - 0s 44ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - mean_absolute_error: 0.0491 - val_loss: 0.0038 - val_mean_squared_error: 0.0038 - val_mean_absolute_error: 0.0448

# %% [markdown]
# ## Punto 2 - Red Neuronal multicapa
#
# En la celda 2 creen una **red neuronal con dos capas** con la librería Keras, que prediga la probabilidad de admisión de los estudiantes usando los sets de entrenamiento y test definidos anteriormente. Pueden usar la función de perdida, el optimizador, el número de épocas y el número de neuronas que consideren pertinentes para el modelo, justificando su selección. Finalmente, grafiquen la pérdida del modelo vs el número de épocas en el set de entrenamiento y validación, y presenten el desempeño del modelo con las métricas error absoluto medio (MAE) y error cuadrático medio (MSE).

# %%
# Celda 2
K.clear_session()

# Definición red neuronal con la función Sequential()
model = Sequential()

# Definición de la capa densa con un tamaño de salida igual a output_var y un input_shape de dims
model.add(Dense(256, input_shape=(dims,),activation='relu'))
model.add(Dense(256,activation='relu'))
model.add(Dense(output_var))
model.add(Activation('relu'))

# Impresión de la arquitectura de la red neuronal
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               2048
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dense_2 (Dense)             (None, 1)                 257
#
#  activation (Activation)     (None, 1)                 0
#
# =================================================================
# Total params: 68,097
# Trainable params: 68,097
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Definición de función de perdida. Se usa mean_squared_error dado que es un ejercicio de regresión
model.compile(optimizer='sgd', loss='mean_squared_error',  metrics=['mean_squared_error', 'mean_absolute_error'])

# %%
# Separación de datos de entrenamiento para considerar un set de validación durante entrenamiento
X_train, X_val, Y_train, Y_val = train_test_split(xTrain, yTrain, test_size=0.15, random_state=42)

# %%
# Entrenamiento de la red neuronal con 50 épocas
model.fit(X_train, Y_train,
          validation_data = (X_val, Y_val),
          epochs=50, 
          callbacks=[PlotLossesKeras()])
# Out:
# Loss
# 	training         	 (min:    0.541, max:    0.541, cur:    0.541)
# 	validation       	 (min:    0.580, max:    0.580, cur:    0.580)
# mean_absolute_error
# 	training         	 (min:    0.722, max:    0.722, cur:    0.722)
# 	validation       	 (min:    0.750, max:    0.750, cur:    0.750)
# mean_squared_error
# 	training         	 (min:    0.541, max:    0.541, cur:    0.541)
# 	validation       	 (min:    0.580, max:    0.580, cur:    0.580)
# 10/10 [==============================] - 0s 49ms/step - loss: 0.5410 - mean_squared_error: 0.5410 - mean_absolute_error: 0.7223 - val_loss: 0.5805 - val_mean_squared_error: 0.5805 - val_mean_absolute_error: 0.7497

# %% [markdown]
# ## Punto 3  - Red Neuronal multicapa
#
# En la celda 3 creen **una red neuronal con más de una capa con la librería Keras, usando early stopping y dropout,** que prediga la probabilidad de admisión de los estudiantes con los sets de entrenamiento y test definidos anteriormente. Pueden usar la función de perdida, el optimizador, el número de épocas y el número de neuronas que consideren pertinentes para el modelo, justificando su selección. Finalmente, grafiquen la pérdida del modelo vs el número de épocas en el set de entrenamiento y validación, y presenten el desempeño del modelo con las métricas error absoluto medio (MAE) y error cuadrático medio (MSE).

# %%
# Celda 3
K.clear_session()

# Definición red neuronal con la función Sequential()
model = Sequential()

# Definición de la capa densa con un tamaño de salida igual a output_var y un input_shape de dims
model.add(Dense(256, input_shape=(dims,),activation='relu'))
model.add(Dense(256,activation='relu'))
model.add(Dense(output_var))
model.add(Activation('relu'))

# Impresión de la arquitectura de la red neuronal
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               2048
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dense_2 (Dense)             (None, 1)                 257
#
#  activation (Activation)     (None, 1)                 0
#
# =================================================================
# Total params: 68,097
# Trainable params: 68,097
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint

# Definición de la función EarlyStopping para considerar durante el entrenamiento
early_stop = EarlyStopping(monitor='val_loss', patience=2, verbose=1) 

# Definición de la función ModelCheckpoint para guardar el modelo con mejor desempeño
fBestModel = 'best_model.h5'
best_model = ModelCheckpoint(fBestModel, verbose=0, save_best_only=True)

# %%
# Definición de función de perdida. Se usa mean_squared_error dado que es un ejercicio de regresión
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
# Separación de datos de entrenamiento para considerar un set de validación durante entrenamiento
X_train, X_val, Y_train, Y_val = train_test_split(xTrain, yTrain, test_size=0.15, random_state=42)

# %%
# Entrenamiento de la red neuronal con 50 épocas y early stopping
model.fit(X_train, Y_train, 
          verbose=True, 
          validation_data = (X_val, Y_val),
          epochs=50, 
          batch_size=128,
          callbacks=[best_model, early_stop])
# Out:
# Epoch 1/50
# 3/3 [==============================] - 1s 239ms/step - loss: 0.5328 - val_loss: 0.5352
# Epoch 2/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4698 - val_loss: 0.3568
# Epoch 3/50
# 3/3 [==============================] - 0s 15ms/step - loss: 0.3062 - val_loss: 0.2158
# Epoch 4/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1823 - val_loss: 0.1355
# Epoch 5/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1156 - val_loss: 0.0940
# Epoch 6/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0814 - val_loss: 0.0723
# Epoch 7/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0638 - val_loss: 0.0611
# Epoch 8/50
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0547 - val_loss: 0.0540
# Epoch 9/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0489 - val_loss: 0.0491
# Epoch 10/50
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0452 - val_loss: 0.0457
# Epoch 11/50
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0423 - val_loss: 0.0427
# Epoch 12/50
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0399 - val_loss: 0.0400
# Epoch 13/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0376 - val_loss: 0.0377
# Epoch 14/50
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0357 - val_loss: 0.0357
# Epoch 15/50
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0338 - val_loss: 0.0338
# Epoch 16/50
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0321 - val_loss: 0.0320
# Epoch 17/50
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0305 - val_loss: 0.0306
# Epoch 18/50
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0290 - val_loss: 0.0291
# Epoch 19/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0276 - val_loss: 0.0277
# Epoch 20/50
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0263 - val_loss: 0.0266
# Epoch 21/50
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0251 - val_loss: 0.0253
# Epoch 22/50
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0239 - val_loss: 0.0243
# Epoch 23/50
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0228 - val_loss: 0.0234
# Epoch 24/50
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0218 - val_loss: 0.0223
# Epoch 25/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0209 - val_loss: 0.0214
# Epoch 26/50
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0200 - val_loss: 0.0203
# Epoch 27/50
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0191 - val_loss: 0.0194
# Epoch 28/50
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0183 - val_loss: 0.0185
# Epoch 29/50
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0176 - val_loss: 0.0178
# Epoch 30/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0169 - val_loss: 0.0170
# Epoch 31/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0163 - val_loss: 0.0163
# Epoch 32/50
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0156 - val_loss: 0.0157
# Epoch 33/50
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0150 - val_loss: 0.0151
# Epoch 34/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0145 - val_loss: 0.0145
# Epoch 35/50
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0140 - val_loss: 0.0139
# Epoch 36/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0135 - val_loss: 0.0136
# Epoch 37/50
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0131 - val_loss: 0.0131
# Epoch 38/50
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0127 - val_loss: 0.0127
# Epoch 39/50
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0123 - val_loss: 0.0122
# Epoch 40/50
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0119 - val_loss: 0.0119
# Epoch 41/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0115 - val_loss: 0.0114
# Epoch 42/50
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0112 - val_loss: 0.0110
# Epoch 43/50
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0109 - val_loss: 0.0107
# Epoch 44/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0106 - val_loss: 0.0105
# Epoch 45/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0103 - val_loss: 0.0102
# Epoch 46/50
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0101 - val_loss: 0.0099
# Epoch 47/50
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0099 - val_loss: 0.0096
# Epoch 48/50
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0096 - val_loss: 0.0093
# Epoch 49/50
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0094 - val_loss: 0.0091
# Epoch 50/50
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0092 - val_loss: 0.0089

# %% [markdown]
# ## Punto 4 - Comparación y análisis de resultados
#
# En la celda 4 comparen los resultados obtenidos de las diferentes redes y comenten las ventajas del mejor modelo y las desventajas del modelo con el menor desempeño.

# %%
# Celda 4
